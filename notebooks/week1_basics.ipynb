# %%
a = 10 
print(a, type(a))
# Out:
# 10 <class 'int'>

# %%
a = 10
b = 5

# %%
print(a + b, a - b, a * b, a / b)
# Out:
# 15 5 50 2.0

# %%
def greet(name):
    return f"Hello, {name}!"

# %%
print(greet("Karan"))
# Out:
# Hello, Karan!
